# %%
import pandas as pd
from numpy import *

dataSet = [line.split() for line in open('/content/sample_data/mushroom.dat').readlines()]

# %%
def createC1(dataSet):
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
                
    C1.sort()
    return list(map(frozenset, C1))

# %%
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if not can in ssCnt: ssCnt[can]=1
                else: ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key]/numItems
        if support >= minSupport:
            retList.insert(0,key)
        supportData[key] = support
    return retList, supportData

# %%
C1 = createC1(dataSet)

# %%
D = list(map(set,dataSet))

# %%
L1,suppDat0 = scanD(D,C1,0.5)
L1
# Out:
# [frozenset({'53'}),
#  frozenset({'24'}),
#  frozenset({'39'}),
#  frozenset({'2'}),
#  frozenset({'90'}),
#  frozenset({'86'}),
#  frozenset({'85'}),
#  frozenset({'76'}),
#  frozenset({'67'}),
#  frozenset({'63'}),
#  frozenset({'59'}),
#  frozenset({'36'}),
#  frozenset({'34'})]

# %%
def aprioriGen(Lk, k): #creates Ck
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk): 
            L1 = list(Lk[i])[:k-2]; L2 = list(Lk[j])[:k-2]
            L1.sort(); L2.sort()
            if L1==L2: #if first k-2 elements are equal
                retList.append(Lk[i] | Lk[j]) #set union
    return retList

# %%
def apriori(dataSet, minSupport):
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport)#scan DB to get Lk
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData

# %%
L,suppData = apriori(dataSet, minSupport = 0.5)
L[0]
# Out:
# [frozenset({'53'}),
#  frozenset({'24'}),
#  frozenset({'39'}),
#  frozenset({'2'}),
#  frozenset({'90'}),
#  frozenset({'86'}),
#  frozenset({'85'}),
#  frozenset({'76'}),
#  frozenset({'67'}),
#  frozenset({'63'}),
#  frozenset({'59'}),
#  frozenset({'36'}),
#  frozenset({'34'})]

# %%
aprioriGen(L[0],2)
# Out:
# [frozenset({'24', '53'}),
#  frozenset({'39', '53'}),
#  frozenset({'2', '53'}),
#  frozenset({'53', '90'}),
#  frozenset({'53', '86'}),
#  frozenset({'53', '85'}),
#  frozenset({'53', '76'}),
#  frozenset({'53', '67'}),
#  frozenset({'53', '63'}),
#  frozenset({'53', '59'}),
#  frozenset({'36', '53'}),
#  frozenset({'34', '53'}),
#  frozenset({'24', '39'}),
#  frozenset({'2', '24'}),
#  frozenset({'24', '90'}),
#  frozenset({'24', '86'}),
#  frozenset({'24', '85'}),
#  frozenset({'24', '76'}),
#  frozenset({'24', '67'}),
#  frozenset({'24', '63'}),
#  frozenset({'24', '59'}),
#  frozenset({'24', '36'}),
#  frozenset({'24', '34'}),
#  frozenset({'2', '39'}),
#  frozenset({'39', '90'}),
#  frozenset({'39', '86'}),
#  frozenset({'39', '85'}),
#  frozenset({'39', '76'}),
#  frozenset({'39', '67'}),
#  frozenset({'39', '63'}),
#  frozenset({'39', '59'}),
#  frozenset({'36', '39'}),
#  frozenset({'34', '39'}),
#  frozenset({'2', '90'}),
#  frozenset({'2', '86'}),
#  frozenset({'2', '85'}),
#  frozenset({'2', '76'}),
#  frozenset({'2', '67'}),
#  frozenset({'2', '63'}),
#  frozenset({'2', '59'}),
#  frozenset({'2', '36'}),
#  frozenset({'2', '34'}),
#  frozenset({'86', '90'}),
#  frozenset({'85', '90'}),
#  frozenset({'76', '90'}),
#  frozenset({'67', '90'}),
#  frozenset({'63', '90'}),
#  frozenset({'59', '90'}),
#  frozenset({'36', '90'}),
#  frozenset({'34', '90'}),
#  frozenset({'85', '86'}),
#  frozenset({'76', '86'}),
#  frozenset({'67', '86'}),
#  frozenset({'63', '86'}),
#  frozenset({'59', '86'}),
#  frozenset({'36', '86'}),
#  frozenset({'34', '86'}),
#  frozenset({'76', '85'}),
#  frozenset({'67', '85'}),
#  frozenset({'63', '85'}),
#  frozenset({'59', '85'}),
#  frozenset({'36', '85'}),
#  frozenset({'34', '85'}),
#  frozenset({'67', '76'}),
#  frozenset({'63', '76'}),
#  frozenset({'59', '76'}),
#  frozenset({'36', '76'}),
#  frozenset({'34', '76'}),
#  frozenset({'63', '67'}),
#  frozenset({'59', '67'}),
#  frozenset({'36', '67'}),
#  frozenset({'34', '67'}),
#  frozenset({'59', '63'}),
#  frozenset({'36', '63'}),
#  frozenset({'34', '63'}),
#  frozenset({'36', '59'}),
#  frozenset({'34', '59'}),
#  frozenset({'34', '36'})]

# %%
def generateRules(L, supportData, minConf):  #supportData is a dict coming from scanD
    bigRuleList = []
    for i in range(1, len(L)):#only get the sets with two or more items
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %%
def calcConf(freqSet, H, supportData, brl, minConf):
    prunedH = [] #create new list to return
    for conseq in H:
        conf = supportData[freqSet]/supportData[freqSet-conseq] #calc confidence
        if conf >= minConf: 
            print (freqSet-conseq,'-->',conseq,'conf:',conf)
            brl.append((freqSet-conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

# %%
def rulesFromConseq(freqSet, H, supportData, brl, minConf):
    m = len(H[0])
    if (len(freqSet) > (m + 1)): #try further merging
        Hmp1 = aprioriGen(H, m+1)#create Hm+1 new candidates
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)
        if (len(Hmp1) > 1):    #need at least two sets to merge
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)

# %%
L,suppData= apriori(dataSet,minSupport=0.5)

# %%
rules= generateRules(L,suppData, minConf=0.8)
# Out:
# frozenset({'24'}) --> frozenset({'34'}) conf: 0.9557708508845831
# frozenset({'24'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'24'}) --> frozenset({'86'}) conf: 0.95787700084246
# frozenset({'24'}) --> frozenset({'90'}) conf: 0.9283909014321822
# frozenset({'53'}) --> frozenset({'34'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'86'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'90'}) conf: 1.0
# frozenset({'2'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'39'}) --> frozenset({'34'}) conf: 0.9625801853171776
# frozenset({'39'}) --> frozenset({'36'}) conf: 0.811831789023521
# frozenset({'39'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'39'}) --> frozenset({'86'}) conf: 0.9657875980042766
# frozenset({'39'}) --> frozenset({'90'}) conf: 0.8866714183891662
# frozenset({'34'}) --> frozenset({'36'}) conf: 0.834217841799343
# frozenset({'36'}) --> frozenset({'34'}) conf: 0.9691720493247211
# frozenset({'59'}) --> frozenset({'34'}) conf: 0.9629057187017002
# frozenset({'59'}) --> frozenset({'36'}) conf: 0.8547140649149924
# frozenset({'63'}) --> frozenset({'34'}) conf: 0.9611021069692057
# frozenset({'63'}) --> frozenset({'36'}) conf: 0.8476499189627228
# frozenset({'59'}) --> frozenset({'63'}) conf: 0.8029366306027821
# frozenset({'63'}) --> frozenset({'59'}) conf: 0.8419773095623986
# frozenset({'67'}) --> frozenset({'34'}) conf: 1.0
# frozenset({'76'}) --> frozenset({'34'}) conf: 1.0
# frozenset({'34'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'85'}) --> frozenset({'34'}) conf: 0.9741506646971935
# frozenset({'36'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'85'}) --> frozenset({'36'}) conf: 0.8385032003938946
# frozenset({'59'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'63'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'67'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'76'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'34'}) --> frozenset({'86'}) conf: 0.9989891331817033
# frozenset({'86'}) --> frozenset({'34'}) conf: 0.997728419989904
# frozenset({'36'}) --> frozenset({'86'}) conf: 0.9718144450968879
# frozenset({'86'}) --> frozenset({'36'}) conf: 0.8354366481574962
# frozenset({'59'}) --> frozenset({'86'}) conf: 0.9629057187017002
# frozenset({'63'}) --> frozenset({'86'}) conf: 0.9611021069692057
# frozenset({'67'}) --> frozenset({'86'}) conf: 1.0
# frozenset({'76'}) --> frozenset({'86'}) conf: 1.0
# frozenset({'85'}) --> frozenset({'86'}) conf: 0.9753815854258986
# frozenset({'86'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'34'}) --> frozenset({'90'}) conf: 0.9219105382865808
# frozenset({'90'}) --> frozenset({'34'}) conf: 0.9743589743589743
# frozenset({'36'}) --> frozenset({'90'}) conf: 0.9489136817381092
# frozenset({'90'}) --> frozenset({'36'}) conf: 0.8632478632478632
# frozenset({'59'}) --> frozenset({'90'}) conf: 0.9149922720247294
# frozenset({'63'}) --> frozenset({'90'}) conf: 0.9108589951377632
# frozenset({'85'}) --> frozenset({'90'}) conf: 0.9217134416543574
# frozenset({'90'}) --> frozenset({'85'}) conf: 1.0
# frozenset({'86'}) --> frozenset({'90'}) conf: 0.9197375063099444
# frozenset({'90'}) --> frozenset({'86'}) conf: 0.9732905982905983
# frozenset({'53'}) --> frozenset({'90', '86'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'90', '85'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'90', '34'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'86', '34'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'24'}) --> frozenset({'90', '86'}) conf: 0.8862679022746419
# frozenset({'24'}) --> frozenset({'90', '85'}) conf: 0.9283909014321822
# frozenset({'24'}) --> frozenset({'90', '34'}) conf: 0.8879528222409435
# frozenset({'24'}) --> frozenset({'86', '85'}) conf: 0.95787700084246
# frozenset({'24'}) --> frozenset({'86', '34'}) conf: 0.9540859309182815
# frozenset({'24'}) --> frozenset({'85', '34'}) conf: 0.9557708508845831
# frozenset({'39'}) --> frozenset({'90', '86'}) conf: 0.8524590163934428
# frozenset({'39'}) --> frozenset({'90', '85'}) conf: 0.8866714183891662
# frozenset({'39'}) --> frozenset({'90', '34'}) conf: 0.8524590163934428
# frozenset({'39'}) --> frozenset({'86', '85'}) conf: 0.9657875980042766
# frozenset({'39'}) --> frozenset({'86', '34'}) conf: 0.9625801853171776
# frozenset({'39'}) --> frozenset({'85', '36'}) conf: 0.811831789023521
# frozenset({'39'}) --> frozenset({'85', '34'}) conf: 0.9625801853171776
# frozenset({'85'}) --> frozenset({'90', '86'}) conf: 0.897095027080256
# frozenset({'86'}) --> frozenset({'90', '85'}) conf: 0.9197375063099444
# frozenset({'90'}) --> frozenset({'86', '85'}) conf: 0.9732905982905983
# frozenset({'63'}) --> frozenset({'90', '86'}) conf: 0.8719611021069692
# frozenset({'63'}) --> frozenset({'90', '85'}) conf: 0.9108589951377632
# frozenset({'59'}) --> frozenset({'90', '86'}) conf: 0.8778979907264296
# frozenset({'59'}) --> frozenset({'90', '85'}) conf: 0.9149922720247294
# frozenset({'36'}) --> frozenset({'90', '86'}) conf: 0.920728126834997
# frozenset({'90'}) --> frozenset({'86', '36'}) conf: 0.8376068376068376
# frozenset({'36'}) --> frozenset({'90', '85'}) conf: 0.9489136817381092
# frozenset({'59'}) --> frozenset({'85', '34'}) conf: 0.9629057187017002
# frozenset({'59'}) --> frozenset({'36', '34'}) conf: 0.8176197836166923
# frozenset({'85', '24'}) --> frozenset({'86', '34'}) conf: 0.9540859309182815
# frozenset({'86', '24'}) --> frozenset({'85', '34'}) conf: 0.9960422163588392
# frozenset({'24', '34'}) --> frozenset({'86', '85'}) conf: 0.998237108858528
# frozenset({'24'}) --> frozenset({'86', '85', '34'}) conf: 0.9540859309182815
# frozenset({'85', '24'}) --> frozenset({'90', '34'}) conf: 0.8879528222409435
# frozenset({'90', '24'}) --> frozenset({'85', '34'}) conf: 0.9564428312159707
# frozenset({'24', '34'}) --> frozenset({'90', '85'}) conf: 0.9290436315557513
# frozenset({'24'}) --> frozenset({'90', '85', '34'}) conf: 0.8879528222409435
# frozenset({'86', '24'}) --> frozenset({'90', '34'}) conf: 0.9252418645558487
# frozenset({'90', '24'}) --> frozenset({'86', '34'}) conf: 0.954627949183303
# frozenset({'24', '34'}) --> frozenset({'90', '86'}) conf: 0.9272807404142793
# frozenset({'24'}) --> frozenset({'90', '86', '34'}) conf: 0.8862679022746419
# frozenset({'85', '24'}) --> frozenset({'90', '86'}) conf: 0.8862679022746419
# frozenset({'86', '24'}) --> frozenset({'90', '85'}) conf: 0.9252418645558487
# frozenset({'90', '24'}) --> frozenset({'86', '85'}) conf: 0.954627949183303
# frozenset({'24'}) --> frozenset({'90', '86', '85'}) conf: 0.8862679022746419
# frozenset({'85', '53'}) --> frozenset({'86', '34'}) conf: 1.0
# frozenset({'86', '53'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'53', '34'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'86', '85', '34'}) conf: 1.0
# frozenset({'85', '53'}) --> frozenset({'90', '34'}) conf: 1.0
# frozenset({'90', '53'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'53', '34'}) --> frozenset({'90', '85'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'90', '85', '34'}) conf: 1.0
# frozenset({'86', '53'}) --> frozenset({'90', '34'}) conf: 1.0
# frozenset({'90', '53'}) --> frozenset({'86', '34'}) conf: 1.0
# frozenset({'53', '34'}) --> frozenset({'90', '86'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'90', '86', '34'}) conf: 1.0
# frozenset({'85', '53'}) --> frozenset({'90', '86'}) conf: 1.0
# frozenset({'86', '53'}) --> frozenset({'90', '85'}) conf: 1.0
# frozenset({'90', '53'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'90', '86', '85'}) conf: 1.0
# frozenset({'39', '34'}) --> frozenset({'85', '36'}) conf: 0.8045168456127361
# frozenset({'39', '36'}) --> frozenset({'85', '34'}) conf: 0.953906935908692
# frozenset({'86', '39'}) --> frozenset({'36', '34'}) conf: 0.8018450184501846
# frozenset({'36'}) --> frozenset({'90', '86', '34'}) conf: 0.920728126834997
# frozenset({'59', '85'}) --> frozenset({'90', '34'}) conf: 0.8778979907264296
# frozenset({'90', '59'}) --> frozenset({'85', '34'}) conf: 0.9594594594594594
# frozenset({'59', '34'}) --> frozenset({'90', '85'}) conf: 0.9117174959871588
# frozenset({'59'}) --> frozenset({'90', '85', '34'}) conf: 0.8778979907264296
# frozenset({'90', '59'}) --> frozenset({'85', '36'}) conf: 0.8716216216216217
# frozenset({'59', '36'}) --> frozenset({'90', '85'}) conf: 0.9330922242314647
# frozenset({'86', '59'}) --> frozenset({'90', '34'}) conf: 0.9117174959871588
# frozenset({'90', '59'}) --> frozenset({'86', '34'}) conf: 0.9594594594594594
# frozenset({'59', '34'}) --> frozenset({'90', '86'}) conf: 0.9117174959871588
# frozenset({'59'}) --> frozenset({'90', '86', '34'}) conf: 0.8778979907264296
# frozenset({'63', '85'}) --> frozenset({'90', '34'}) conf: 0.8719611021069692
# frozenset({'90', '63'}) --> frozenset({'85', '34'}) conf: 0.9572953736654805
# frozenset({'63', '34'}) --> frozenset({'90', '85'}) conf: 0.9072512647554807
# frozenset({'63'}) --> frozenset({'90', '85', '34'}) conf: 0.8719611021069692
# frozenset({'86', '63'}) --> frozenset({'90', '34'}) conf: 0.9072512647554807
# frozenset({'90', '63'}) --> frozenset({'86', '34'}) conf: 0.9572953736654805
# frozenset({'63', '34'}) --> frozenset({'90', '86'}) conf: 0.9072512647554807
# frozenset({'63'}) --> frozenset({'90', '86', '34'}) conf: 0.8719611021069692
# frozenset({'86', '85'}) --> frozenset({'90', '34'}) conf: 0.9197375063099444
# frozenset({'90', '85'}) --> frozenset({'86', '34'}) conf: 0.9732905982905983
# frozenset({'90', '86'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'85', '34'}) --> frozenset({'90', '86'}) conf: 0.9208996714682841
# frozenset({'86', '34'}) --> frozenset({'90', '85'}) conf: 0.9218315203642803
# frozenset({'90', '34'}) --> frozenset({'86', '85'}) conf: 0.9989035087719298
# frozenset({'85'}) --> frozenset({'90', '86', '34'}) conf: 0.897095027080256
# frozenset({'86'}) --> frozenset({'90', '85', '34'}) conf: 0.9197375063099444
# frozenset({'90'}) --> frozenset({'86', '85', '34'}) conf: 0.9732905982905983
# frozenset({'34'}) --> frozenset({'90', '86', '85'}) conf: 0.9208996714682841
# frozenset({'90', '85'}) --> frozenset({'86', '36'}) conf: 0.8376068376068376
# frozenset({'90', '86'}) --> frozenset({'85', '36'}) conf: 0.8605927552140504
# frozenset({'85', '36'}) --> frozenset({'90', '86'}) conf: 0.920728126834997
# frozenset({'86', '36'}) --> frozenset({'90', '85'}) conf: 0.9474320241691843
# frozenset({'90', '36'}) --> frozenset({'86', '85'}) conf: 0.9702970297029703
# frozenset({'90'}) --> frozenset({'86', '85', '36'}) conf: 0.8376068376068376
# frozenset({'36'}) --> frozenset({'90', '86', '85'}) conf: 0.920728126834997
# frozenset({'59', '85'}) --> frozenset({'90', '86'}) conf: 0.8778979907264296
# frozenset({'86', '59'}) --> frozenset({'90', '85'}) conf: 0.9117174959871588
# frozenset({'90', '59'}) --> frozenset({'86', '85'}) conf: 0.9594594594594594
# frozenset({'59'}) --> frozenset({'90', '86', '85'}) conf: 0.8778979907264296
# frozenset({'63', '85'}) --> frozenset({'90', '86'}) conf: 0.8719611021069692
# frozenset({'86', '63'}) --> frozenset({'90', '85'}) conf: 0.9072512647554807
# frozenset({'90', '63'}) --> frozenset({'86', '85'}) conf: 0.9572953736654805
# frozenset({'63'}) --> frozenset({'90', '86', '85'}) conf: 0.8719611021069692
# frozenset({'86', '85', '53'}) --> frozenset({'90', '34'}) conf: 1.0
# frozenset({'90', '85', '53'}) --> frozenset({'86', '34'}) conf: 1.0
# frozenset({'90', '86', '53'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'53', '85', '34'}) --> frozenset({'90', '86'}) conf: 1.0
# frozenset({'86', '53', '34'}) --> frozenset({'90', '85'}) conf: 1.0
# frozenset({'90', '53', '34'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'85', '53'}) --> frozenset({'90', '86', '34'}) conf: 1.0
# frozenset({'86', '53'}) --> frozenset({'90', '85', '34'}) conf: 1.0
# frozenset({'90', '53'}) --> frozenset({'86', '85', '34'}) conf: 1.0
# frozenset({'53', '34'}) --> frozenset({'90', '86', '85'}) conf: 1.0
# frozenset({'53'}) --> frozenset({'34', '90', '86', '85'}) conf: 1.0
# frozenset({'86', '85', '24'}) --> frozenset({'90', '34'}) conf: 0.9252418645558487
# frozenset({'90', '85', '24'}) --> frozenset({'86', '34'}) conf: 0.954627949183303
# frozenset({'90', '86', '24'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'24', '85', '34'}) --> frozenset({'90', '86'}) conf: 0.9272807404142793
# frozenset({'86', '24', '34'}) --> frozenset({'90', '85'}) conf: 0.9289183222958056
# frozenset({'90', '24', '34'}) --> frozenset({'86', '85'}) conf: 0.9981024667931689
# frozenset({'85', '24'}) --> frozenset({'90', '86', '34'}) conf: 0.8862679022746419
# frozenset({'86', '24'}) --> frozenset({'90', '85', '34'}) conf: 0.9252418645558487
# frozenset({'90', '24'}) --> frozenset({'86', '85', '34'}) conf: 0.954627949183303
# frozenset({'24', '34'}) --> frozenset({'90', '86', '85'}) conf: 0.9272807404142793
# frozenset({'24'}) --> frozenset({'34', '90', '86', '85'}) conf: 0.8862679022746419
# frozenset({'86', '39', '85'}) --> frozenset({'90', '34'}) conf: 0.8826568265682658
# frozenset({'90', '39', '85'}) --> frozenset({'86', '34'}) conf: 0.9614147909967846
# frozenset({'90', '86', '39'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'39', '85', '34'}) --> frozenset({'90', '86'}) conf: 0.8855979266938171
# frozenset({'86', '39', '34'}) --> frozenset({'90', '85'}) conf: 0.8855979266938171
# frozenset({'90', '39', '34'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'39', '85'}) --> frozenset({'90', '86', '34'}) conf: 0.8524590163934428
# frozenset({'86', '39'}) --> frozenset({'90', '85', '34'}) conf: 0.8826568265682658
# frozenset({'90', '39'}) --> frozenset({'86', '85', '34'}) conf: 0.9614147909967846
# frozenset({'39', '34'}) --> frozenset({'90', '86', '85'}) conf: 0.8855979266938171
# frozenset({'39'}) --> frozenset({'34', '90', '86', '85'}) conf: 0.8524590163934428
# frozenset({'39', '85', '36'}) --> frozenset({'86', '34'}) conf: 0.953906935908692
# frozenset({'86', '39', '36'}) --> frozenset({'85', '34'}) conf: 0.9958753437213567
# frozenset({'86', '39', '85'}) --> frozenset({'36', '34'}) conf: 0.8018450184501846
# frozenset({'39', '36', '34'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'39', '85', '34'}) --> frozenset({'86', '36'}) conf: 0.8045168456127361
# frozenset({'86', '39', '34'}) --> frozenset({'85', '36'}) conf: 0.8045168456127361
# frozenset({'39', '36'}) --> frozenset({'86', '85', '34'}) conf: 0.953906935908692
# frozenset({'86', '39'}) --> frozenset({'85', '36', '34'}) conf: 0.8018450184501846
# frozenset({'39', '34'}) --> frozenset({'86', '85', '36'}) conf: 0.8045168456127361
# frozenset({'86', '63', '85'}) --> frozenset({'90', '34'}) conf: 0.9072512647554807
# frozenset({'90', '63', '85'}) --> frozenset({'86', '34'}) conf: 0.9572953736654805
# frozenset({'90', '86', '63'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'63', '85', '34'}) --> frozenset({'90', '86'}) conf: 0.9072512647554807
# frozenset({'86', '63', '34'}) --> frozenset({'90', '85'}) conf: 0.9072512647554807
# frozenset({'90', '63', '34'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'63', '85'}) --> frozenset({'90', '86', '34'}) conf: 0.8719611021069692
# frozenset({'86', '63'}) --> frozenset({'90', '85', '34'}) conf: 0.9072512647554807
# frozenset({'90', '63'}) --> frozenset({'86', '85', '34'}) conf: 0.9572953736654805
# frozenset({'63', '34'}) --> frozenset({'90', '86', '85'}) conf: 0.9072512647554807
# frozenset({'63'}) --> frozenset({'34', '90', '86', '85'}) conf: 0.8719611021069692
# frozenset({'86', '59', '85'}) --> frozenset({'90', '34'}) conf: 0.9117174959871588
# frozenset({'90', '59', '85'}) --> frozenset({'86', '34'}) conf: 0.9594594594594594
# frozenset({'90', '86', '59'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'59', '85', '34'}) --> frozenset({'90', '86'}) conf: 0.9117174959871588
# frozenset({'86', '59', '34'}) --> frozenset({'90', '85'}) conf: 0.9117174959871588
# frozenset({'90', '59', '34'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'59', '85'}) --> frozenset({'90', '86', '34'}) conf: 0.8778979907264296
# frozenset({'86', '59'}) --> frozenset({'90', '85', '34'}) conf: 0.9117174959871588
# frozenset({'90', '59'}) --> frozenset({'86', '85', '34'}) conf: 0.9594594594594594
# frozenset({'59', '34'}) --> frozenset({'90', '86', '85'}) conf: 0.9117174959871588
# frozenset({'59'}) --> frozenset({'34', '90', '86', '85'}) conf: 0.8778979907264296
# frozenset({'86', '85', '36'}) --> frozenset({'90', '34'}) conf: 0.9474320241691843
# frozenset({'90', '85', '36'}) --> frozenset({'86', '34'}) conf: 0.9702970297029703
# frozenset({'90', '86', '36'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'90', '86', '85'}) --> frozenset({'36', '34'}) conf: 0.8605927552140504
# frozenset({'85', '36', '34'}) --> frozenset({'90', '86'}) conf: 0.9500151469251741
# frozenset({'86', '36', '34'}) --> frozenset({'90', '85'}) conf: 0.9500151469251741
# frozenset({'90', '36', '34'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'90', '85', '34'}) --> frozenset({'86', '36'}) conf: 0.8596491228070176
# frozenset({'90', '86', '34'}) --> frozenset({'85', '36'}) conf: 0.8605927552140504
# frozenset({'85', '36'}) --> frozenset({'90', '86', '34'}) conf: 0.920728126834997
# frozenset({'86', '36'}) --> frozenset({'90', '85', '34'}) conf: 0.9474320241691843
# frozenset({'90', '36'}) --> frozenset({'86', '85', '34'}) conf: 0.9702970297029703
# frozenset({'90', '85'}) --> frozenset({'86', '36', '34'}) conf: 0.8376068376068376
# frozenset({'90', '86'}) --> frozenset({'85', '36', '34'}) conf: 0.8605927552140504
# frozenset({'36', '34'}) --> frozenset({'90', '86', '85'}) conf: 0.9500151469251741
# frozenset({'90', '34'}) --> frozenset({'86', '85', '36'}) conf: 0.8596491228070176
# frozenset({'36'}) --> frozenset({'34', '90', '86', '85'}) conf: 0.920728126834997
# frozenset({'90'}) --> frozenset({'36', '34', '86', '85'}) conf: 0.8376068376068376
# frozenset({'59', '85', '36'}) --> frozenset({'86', '34'}) conf: 0.9566003616636526
# frozenset({'86', '59', '36'}) --> frozenset({'85', '34'}) conf: 1.0
# frozenset({'86', '59', '85'}) --> frozenset({'36', '34'}) conf: 0.8491171749598715
# frozenset({'59', '36', '34'}) --> frozenset({'86', '85'}) conf: 1.0
# frozenset({'59', '85', '34'}) --> frozenset({'86', '36'}) conf: 0.8491171749598715
# frozenset({'86', '59', '34'}) --> frozenset({'85', '36'}) conf: 0.8491171749598715
# frozenset({'59', '36'}) --> frozenset({'86', '85', '34'}) conf: 0.9566003616636526
# frozenset({'59', '85'}) --> frozenset({'86', '36', '34'}) conf: 0.8176197836166923
# frozenset({'86', '59'}) --> frozenset({'85', '36', '34'}) conf: 0.8491171749598715
# frozenset({'59', '34'}) --> frozenset({'86', '85', '36'}) conf: 0.8491171749598715
# frozenset({'59'}) --> frozenset({'36', '34', '86', '85'}) conf: 0.8176197836166923
